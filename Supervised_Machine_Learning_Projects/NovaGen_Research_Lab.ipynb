# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('novagen_dataset.csv')

# %%
data
# Out:
#        Age   BMI  Blood_Pressure  Cholesterol  Glucose_Level  Heart_Rate  \
# 0      2.0  26.0           111.0        198.0           99.0        72.0
# 1      8.0  24.0           121.0        199.0          103.0        75.0
# 2     81.0  27.0           147.0        203.0          100.0        74.0
# 3     25.0  21.0           150.0        199.0          102.0        70.0
# 4     24.0  26.0           146.0        202.0           99.0        76.0
# ...    ...   ...             ...          ...            ...         ...
# 9544   5.0  22.0           109.0        203.0           98.0        75.0
# 9545  94.0  26.0           144.0        203.0           96.0        72.0
# 9546  10.0  23.0           185.0        198.0          103.0        72.0
# 9547  50.0  29.0           166.0        200.0          100.0        74.0
# 9548  69.0  29.0           178.0        203.0          100.0        75.0
#
#       Sleep_Hours  Exercise_Hours  Water_Intake  Stress_Level  ...  Diet  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                      0
# BMI                      0
# Blood_Pressure           0
# Cholesterol              0
# Glucose_Level            0
# Heart_Rate               0
# Sleep_Hours              0
# Exercise_Hours           0
# Water_Intake             0
# Stress_Level             0
# Target                   0
# Smoking                  0
# Alcohol                  0
# Diet                     0
# MentalHealth             0
# PhysicalActivity         0
# MedicalHistory           0
# Allergies                0
# Diet_Type__Vegan         0
# Diet_Type__Vegetarian    0
# Blood_Group_AB           0
# Blood_Group_B            0
# Blood_Group_O            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9549 entries, 0 to 9548
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    9549 non-null   float64
#  1   BMI                    9549 non-null   float64
#  2   Blood_Pressure         9549 non-null   float64
#  3   Cholesterol            9549 non-null   float64
#  4   Glucose_Level          9549 non-null   float64
#  5   Heart_Rate             9549 non-null   float64
#  6   Sleep_Hours            9549 non-null   float64
#  7   Exercise_Hours         9549 non-null   float64
#  8   Water_Intake           9549 non-null   float64
#  9   Stress_Level           9549 non-null   float64
#  10  Target                 9549 non-null   int64
#  11  Smoking                9549 non-null   int64
#  12  Alcohol                9549 non-null   int64
#  13  Diet                   9549 non-null   int64
# ...

# %%
# Convert data into X and y

X = data.drop("Target", axis=1)
y = data['Target']

# %%
data['Target'].value_counts()
# Out:
# Target
# 1    4979
# 0    4570
# Name: count, dtype: int64

# %%
bool_col = data.select_dtypes(include = 'bool').columns

# %%
# Import the Encoder to encode the boolean values
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(
    sparse_output = False
)

for col in bool_col:
    data[col] = encoder.fit_transform(data[[col]])

# %%
# Now Split the data into train and test data 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state = 42
)

# %%
# Now import the Dicision tree models 
from sklearn.tree import DecisionTreeClassifier

clr_model = DecisionTreeClassifier()

# %%
clr_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predict the out from the model 
from sklearn.metrics import accuracy_score, f1_score, r2_score
y_pred = clr_model.predict(X_test)

print("Accuracy Score : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score :  0.8999162479061976

# %%
# Now We use RadomForestClassifier 
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

print("Accuracy score : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy score :  0.9434673366834171

# %%
# Now We Use Voting classifier 
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

clf1 = LogisticRegression(random_state = 42)
clf2 = RandomForestClassifier(random_state = 42)
clf3 = SVC(probability = True, random_state = 42)

voting_clf = VotingClassifier(
    estimators = [('lr', clf), ('rfc', clf2), ('svc', clf3)],
    voting = 'soft',
    weights = [1, 1.5, 2]
)

# %%
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', RandomForestClassifier()),
#                              ('rfc', RandomForestClassifier(random_state=42)),
#                              ('svc', SVC(probability=True, random_state=42))],
#                  voting='soft', weights=[1, 1.5, 2])

# %%
y_pred = voting_clf.predict(X_test)

print("Accuracy Score : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score :  0.9133165829145728

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

clf1 = LogisticRegression(random_state = 42)
clf2 = DecisionTreeClassifier(random_state = 42)
clf3 = SVC(probability = True, random_state = 42)

voting_clf2 = VotingClassifier(
    estimators = [('lr', clf), ('dtc', clf2), ('svc', clf3)],
    voting = 'soft',
    weights = [1, 1.5, 2]
)

# %%
voting_clf2.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', RandomForestClassifier()),
#                              ('dtc', DecisionTreeClassifier(random_state=42)),
#                              ('svc', SVC(probability=True, random_state=42))],
#                  voting='soft', weights=[1, 1.5, 2])

# %%
y_pred = voting_clf2.predict(X_test)

print("Accuracy Score : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score :  0.916247906197655

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_clf = GradientBoostingClassifier(
    learning_rate = 0.1,
    n_estimators = 100,
    max_depth = 2,
    random_state = 42
)

# %%
gb_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=2, random_state=42)

# %%
y_pred_gb = gb_clf.predict(X_test)

print("Accuracy Score : ", accuracy_score(y_test, y_pred_gb))
# Out:
# Accuracy Score :  0.9003350083752094
